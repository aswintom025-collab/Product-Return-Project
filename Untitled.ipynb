# %% [markdown]
# ### Product Return Project

# %% [markdown]
# ### Load Dataset

# %%
import pandas as pd


dir = "Dataset/returns_dataset.csv"
df = pd.read_csv(dir)

# %% [markdown]
# ### Shape

# %%
print(f"Shape : {df.shape}")
# Out:
# Shape : (12000, 26)

# %%
df
# Out:
#         order_id product_category sub_category     brand  product_price  \
# 0      ORD100000           Beauty     Haircare  Brand_23         844.10
# 1      ORD100001             Toys  Educational   Brand_9         559.90
# 2      ORD100002      Electronics      Laptops  Brand_21        1581.93
# 3      ORD100003      Electronics      Laptops  Brand_30        1301.55
# 4      ORD100004      Electronics      Laptops  Brand_15        1402.90
# ...          ...              ...          ...       ...            ...
# 11995  ORD111995             Home    Furniture  Brand_18         246.32
# 11996  ORD111996            Books     Academic  Brand_20         218.97
# 11997  ORD111997      Electronics      Laptops  Brand_13        1463.52
# 11998  ORD111998      Electronics      Mobiles   Brand_5          96.32
# 11999  ORD111999             Home        Decor  Brand_14         692.16
#
#        discount_percent  product_rating  review_count  fragile_item  \
# ...

# %% [markdown]
# ### Exploratory Data Analysis

# %% [markdown]
# ### Class Distribution

# %%
counts = df.returned.value_counts()
counts
# Out:
# returned
# 0    8355
# 1    3645
# Name: count, dtype: int64

# %% [markdown]
# ### Plot class distribution

# %%
import matplotlib.pyplot as plt

colors = ["#0629c4", "#cc0815"]
ax = df['returned'].value_counts().plot(kind='bar', color = colors)
ax.set_xticklabels(["Not Returned(0)", "Returned(1)"], rotation=0)
plt.xlabel('Target Class Balance')
plt.ylabel('Orders')
plt.title('Class Distribution')
plt.show()

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 12000 entries, 0 to 11999
# Data columns (total 26 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   order_id                  12000 non-null  str
#  1   product_category          12000 non-null  str
#  2   sub_category              12000 non-null  str
#  3   brand                     12000 non-null  str
#  4   product_price             12000 non-null  float64
#  5   discount_percent          12000 non-null  float64
#  6   product_rating            11760 non-null  float64
#  7   review_count              11880 non-null  float64
#  8   fragile_item              12000 non-null  int64
#  9   warranty_available        12000 non-null  int64
#  10  product_return_rate       12000 non-null  float64
#  11  category_return_rate      12000 non-null  float64
#  12  brand_return_rate         12000 non-null  float64
#  13  defect_rate               12000 non-null  float64
# ...

# %%
df.describe().T
# Out:
#                             count        mean          std     min      25%  \
# product_price             12000.0  964.063342  1678.771489  19.510  328.235
# discount_percent          12000.0   33.567167    19.378304   0.000   16.800
# product_rating            11760.0    3.886505     0.635664   1.600    3.500
# review_count              11880.0   69.437205    18.446294  24.000   54.000
# fragile_item              12000.0    0.197083     0.397812   0.000    0.000
# warranty_available        12000.0    0.446500     0.497150   0.000    0.000
# product_return_rate       12000.0    0.132522     0.069787   0.001    0.082
# category_return_rate      12000.0    0.120377     0.049559   0.001    0.087
# brand_return_rate         12000.0    0.131886     0.059397   0.010    0.090
# defect_rate               12000.0    0.060629     0.042730   0.000    0.029
# seller_rating             11820.0    4.090854     0.465778   2.200    3.800
# ...

# %%
df["product_price"].hist()
# Out:
# <Axes: >

# %%
df.isna().sum()
# Out:
# order_id                      0
# product_category              0
# sub_category                  0
# brand                         0
# product_price                 0
# discount_percent              0
# product_rating              240
# review_count                120
# fragile_item                  0
# warranty_available            0
# product_return_rate           0
# category_return_rate          0
# brand_return_rate             0
# defect_rate                   0
# seller_rating               180
# seller_return_rate            0
# fulfillment_type              0
# payment_method                0
# quantity                      0
# shipping_distance_km        120
# delayed_delivery              0
# wishlist_before_purchase      0
# product_page_views            0
# customer_support_calls        0
# chat_interactions             0
# returned                      0
# dtype: int64

# %% [markdown]
# ### check unique values in categorical values

# %%
categorical_values = df[["order_id","product_category", "sub_category", "fulfillment_type", "payment_method"]]


for col in categorical_values:
    print(df[col].value_counts())
    print("---------------------------------------------")
# Out:
# order_id
# ORD100000    1
# ORD100001    1
# ORD100002    1
# ORD100003    1
# ORD100004    1
#             ..
# ORD111995    1
# ORD111996    1
# ORD111997    1
# ORD111998    1
# ORD111999    1
# Name: count, Length: 12000, dtype: int64
# ---------------------------------------------
# product_category
# Fashion        3413
# Electronics    2601
# Home           1816
# Beauty         1453
# Sports         1202
# Books           910
# Toys            605
# Name: count, dtype: int64
# ---------------------------------------------
# sub_category
# Mobiles           904
# Audio             862
# Laptops           835
# Women             706
# Accessories       684
# Footwear          681
# Men               673
# Kids              669
# Furniture         614
# Kitchen           614
# Decor             588
# Haircare          505
# Skincare          485
# Makeup            463
# Team Sports       439
# Fitness           389
# Outdoor           374
# Non-Fiction       335
# ...

# %% [markdown]
# ### Plot return rate based on payment method, product category, fullfillment type

# %%
fig, axes = plt.subplots(1, 3, figsize = (18, 5))
overall = df["returned"].mean()


for ax, col in zip(axes, ["payment_method", "product_category", "fulfillment_type"]):
    rate = df.groupby(col)["returned"].mean().sort_values(ascending = False)
    rate.plot(kind = "bar", ax = ax, color = "#0629c4")
    ax.axhline(overall, color = "#cc0815", ls = "--", lw = 1, label = f"Overall{overall:.2f}")
    ax.set_title(f"Return rate by {col}")
    ax.set_ylabel("Return rate")
    ax.tick_params(axis = "x", rotation = 30)
    ax.legend()
    plt.tight_layout()
plt.show()

# %%
numeric_rows = ["product_price", "discount_percent", "product_rating", "shipping_distance_km", "product_page_views", "defect_rate", "quantity"]


df[numeric_rows].hist(figsize = (15,9), bins = 40, edgecolor = "black")
plt.tight_layout()
plt.show()

# %% [markdown]
# ### Correlation with target

# %%
import numpy as np
corr = df.select_dtypes(include = [np.number]).corr()
corr
# Out:
#                           product_price  discount_percent  product_rating  \
# product_price                  1.000000         -0.016544       -0.009996
# discount_percent              -0.016544          1.000000        0.000143
# product_rating                -0.009996          0.000143        1.000000
# review_count                   0.011318         -0.001287       -0.004054
# fragile_item                   0.004471          0.007751       -0.009272
# warranty_available            -0.005059         -0.014156       -0.013554
# product_return_rate           -0.004302         -0.003496       -0.006133
# category_return_rate          -0.006108          0.018814        0.002965
# brand_return_rate             -0.003224          0.001693       -0.003017
# defect_rate                   -0.020734          0.005724        0.001398
# seller_rating                  0.008962         -0.006852       -0.008732
# seller_return_rate             0.005713         -0.011614        0.007746
# ...

# %% [markdown]
# ### From the correlation matrix clearly see that
# item is fragile, return
#
# item is defected, return
#
# shipping_distance_km, return
#
# delayed_delivery, return
#
# customer_support_calls, return
#
# chat_interactions, return these are linear correlations

# %%
import seaborn as sns
plt.figure(figsize = (12, 10))
sns.heatmap(corr, cmap="coolwarm", center=0, square=True)
plt.title("Numeric Feature Correlation")
plt.show()

# %% [markdown]
# ### Data Cleaning

# %%
df["fulfillment_type"].value_counts()
# Out:
# fulfillment_type
# Marketplace Fulfilled     7193
# Seller Fulfilled          4747
# marketplace fulfilled       60
# Name: count, dtype: int64

# %% [markdown]
# ### Create a new dataframe

# %%
df_clean = df.copy()

# %%
df_clean["fulfillment_type"] = df_clean["fulfillment_type"].astype("string").str.strip().str.title()
df_clean["fulfillment_type"].value_counts()
# Out:
# fulfillment_type
# Marketplace Fulfilled    7253
# Seller Fulfilled         4747
# Name: count, dtype: int64[pyarrow]

# %%
df_clean
# Out:
#         order_id product_category sub_category     brand  product_price  \
# 0      ORD100000           Beauty     Haircare  Brand_23         844.10
# 1      ORD100001             Toys  Educational   Brand_9         559.90
# 2      ORD100002      Electronics      Laptops  Brand_21        1581.93
# 3      ORD100003      Electronics      Laptops  Brand_30        1301.55
# 4      ORD100004      Electronics      Laptops  Brand_15        1402.90
# ...          ...              ...          ...       ...            ...
# 11995  ORD111995             Home    Furniture  Brand_18         246.32
# 11996  ORD111996            Books     Academic  Brand_20         218.97
# 11997  ORD111997      Electronics      Laptops  Brand_13        1463.52
# 11998  ORD111998      Electronics      Mobiles   Brand_5          96.32
# 11999  ORD111999             Home        Decor  Brand_14         692.16
#
#        discount_percent  product_rating  review_count  fragile_item  \
# ...

# %%
df_clean = df_clean.drop(["order_id"], axis = 1)
df_clean
# Out:
#       product_category sub_category     brand  product_price  \
# 0               Beauty     Haircare  Brand_23         844.10
# 1                 Toys  Educational   Brand_9         559.90
# 2          Electronics      Laptops  Brand_21        1581.93
# 3          Electronics      Laptops  Brand_30        1301.55
# 4          Electronics      Laptops  Brand_15        1402.90
# ...                ...          ...       ...            ...
# 11995             Home    Furniture  Brand_18         246.32
# 11996            Books     Academic  Brand_20         218.97
# 11997      Electronics      Laptops  Brand_13        1463.52
# 11998      Electronics      Mobiles   Brand_5          96.32
# 11999             Home        Decor  Brand_14         692.16
#
#        discount_percent  product_rating  review_count  fragile_item  \
# 0                  65.2             2.1          96.0             1
# 1                  30.1             4.1          87.0             0
# ...

# %%
df_clean.drop_duplicates().reset_index(drop = True)
# Out:
#       product_category sub_category     brand  product_price  \
# 0               Beauty     Haircare  Brand_23         844.10
# 1                 Toys  Educational   Brand_9         559.90
# 2          Electronics      Laptops  Brand_21        1581.93
# 3          Electronics      Laptops  Brand_30        1301.55
# 4          Electronics      Laptops  Brand_15        1402.90
# ...                ...          ...       ...            ...
# 11995             Home    Furniture  Brand_18         246.32
# 11996            Books     Academic  Brand_20         218.97
# 11997      Electronics      Laptops  Brand_13        1463.52
# 11998      Electronics      Mobiles   Brand_5          96.32
# 11999             Home        Decor  Brand_14         692.16
#
#        discount_percent  product_rating  review_count  fragile_item  \
# 0                  65.2             2.1          96.0             1
# 1                  30.1             4.1          87.0             0
# ...

# %%
df_clean.isna().sum()
# Out:
# product_category              0
# sub_category                  0
# brand                         0
# product_price                 0
# discount_percent              0
# product_rating              240
# review_count                120
# fragile_item                  0
# warranty_available            0
# product_return_rate           0
# category_return_rate          0
# brand_return_rate             0
# defect_rate                   0
# seller_rating               180
# seller_return_rate            0
# fulfillment_type              0
# payment_method                0
# quantity                      0
# shipping_distance_km        120
# delayed_delivery              0
# wishlist_before_purchase      0
# product_page_views            0
# customer_support_calls        0
# chat_interactions             0
# returned                      0
# dtype: int64

# %%
df_clean = df_clean.dropna()

# %%
df_clean.isna().sum()
# Out:
# product_category            0
# sub_category                0
# brand                       0
# product_price               0
# discount_percent            0
# product_rating              0
# review_count                0
# fragile_item                0
# warranty_available          0
# product_return_rate         0
# category_return_rate        0
# brand_return_rate           0
# defect_rate                 0
# seller_rating               0
# seller_return_rate          0
# fulfillment_type            0
# payment_method              0
# quantity                    0
# shipping_distance_km        0
# delayed_delivery            0
# wishlist_before_purchase    0
# product_page_views          0
# customer_support_calls      0
# chat_interactions           0
# returned                    0
# dtype: int64

# %% [markdown]
# ### Feature Engineering

# %%
def add_feature(d):
    d["total_customer_support"] = d["customer_support_calls"] + d["chat_interactions"]
    d["log_price"] = np.log1p(d["product_price"])
    d = d.drop(["product_price", "customer_support_calls", "chat_interactions"], axis = 1)
    return d

df_feat = add_feature(df_clean)
df_feat
# Out:
#       product_category sub_category     brand  discount_percent  \
# 0               Beauty     Haircare  Brand_23              65.2
# 1                 Toys  Educational   Brand_9              30.1
# 2          Electronics      Laptops  Brand_21              53.4
# 3          Electronics      Laptops  Brand_30              25.3
# 4          Electronics      Laptops  Brand_15              30.6
# ...                ...          ...       ...               ...
# 11995             Home    Furniture  Brand_18              50.8
# 11996            Books     Academic  Brand_20              10.3
# 11997      Electronics      Laptops  Brand_13              32.6
# 11998      Electronics      Mobiles   Brand_5              13.1
# 11999             Home        Decor  Brand_14              15.7
#
#        product_rating  review_count  fragile_item  warranty_available  \
# 0                 2.1          96.0             1                   1
# ...

# %%
df_feat["log_price"].hist()
# Out:
# <Axes: >

# %%
df_feat.to_csv("Dataset\cleaned_returns.csv", index = False)

# %%
new_cols = ["total_customer_support", "log_price"]
df_feat[new_cols].describe().T
# Out:
#                           count      mean       std       min       25%  \
# total_customer_support  11355.0  0.792690  0.888638  0.000000  0.000000
# log_price               11355.0  6.407683  0.920037  3.020913  5.796453
#
#                              50%       75%       max
# total_customer_support  1.000000  1.000000   6.00000
# log_price               6.393875  7.004646  11.08029

# %% [markdown]
# ### Train Test Split

# %%
X = df_feat.drop(["returned"], axis = 1)
y = df_feat["returned"]

# %%
from sklearn.model_selection import train_test_split


X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2, stratify = y, random_state = 10)

# %%
print(f"Training set size : {X_train.shape}")
print(f"Testing set size : {X_test.shape}")
# Out:
# Training set size : (9084, 23)
# Testing set size : (2271, 23)

# %% [markdown]
# ### Outlier Removal

# %%
num_cols = ["log_price", "review_count", "product_page_views", "shipping_distance_km", "discount_percent"]


fig, axes = plt.subplots(1, len(num_cols), figsize = (20, 4))
for ax, c in zip(axes, num_cols):
    sns.boxplot(y = X_train[c], ax = ax, color = "#0629c4")
    ax.set_title(c)
plt.tight_layout()
plt.show()

# %%
outlier_cols = ["log_price"]


mask = pd.Series(True, index = X_train.index)
for c in outlier_cols:
    q1, q3 = X_train[c].quantile(0.25), X_train[c].quantile(0.75)
    upper = q3 + 3 * (q3 - q1)
    mask &= X_train[c] <= upper
removed = (~mask).sum()
X_train, y_train = X_train[mask], y_train[mask]
print(f"Removed {removed} extreme outlier rows from training set. New train shape : {X_train.shape}")
# Out:
# Removed 4 extreme outlier rows from training set. New train shape : (9080, 23)

# %%
df_feat
# Out:
#       product_category sub_category     brand  discount_percent  \
# 0               Beauty     Haircare  Brand_23              65.2
# 1                 Toys  Educational   Brand_9              30.1
# 2          Electronics      Laptops  Brand_21              53.4
# 3          Electronics      Laptops  Brand_30              25.3
# 4          Electronics      Laptops  Brand_15              30.6
# ...                ...          ...       ...               ...
# 11995             Home    Furniture  Brand_18              50.8
# 11996            Books     Academic  Brand_20              10.3
# 11997      Electronics      Laptops  Brand_13              32.6
# 11998      Electronics      Mobiles   Brand_5              13.1
# 11999             Home        Decor  Brand_14              15.7
#
#        product_rating  review_count  fragile_item  warranty_available  \
# 0                 2.1          96.0             1                   1
# ...

# %%
binary_flags = ["fragile_item", "warranty_available", "delayed_delivery", "wishlist_before_purchase"]
categorical_features = ["product_category", "sub_category", "brand", "fulfillment_type", "payment_method"]
numeric_columns = [c for c in X_train.columns if c not in binary_flags + categorical_features]
all_features = binary_flags + categorical_features + numeric_columns

# %%
binary_flags
# Out:
# ['fragile_item',
#  'warranty_available',
#  'delayed_delivery',
#  'wishlist_before_purchase']

# %%
categorical_features
# Out:
# ['product_category',
#  'sub_category',
#  'brand',
#  'fulfillment_type',
#  'payment_method']

# %%
numeric_columns
# Out:
# ['discount_percent',
#  'product_rating',
#  'review_count',
#  'product_return_rate',
#  'category_return_rate',
#  'brand_return_rate',
#  'defect_rate',
#  'seller_rating',
#  'seller_return_rate',
#  'quantity',
#  'shipping_distance_km',
#  'product_page_views',
#  'total_customer_support',
#  'log_price']

# %%
all_features
# Out:
# ['fragile_item',
#  'warranty_available',
#  'delayed_delivery',
#  'wishlist_before_purchase',
#  'product_category',
#  'sub_category',
#  'brand',
#  'fulfillment_type',
#  'payment_method',
#  'discount_percent',
#  'product_rating',
#  'review_count',
#  'product_return_rate',
#  'category_return_rate',
#  'brand_return_rate',
#  'defect_rate',
#  'seller_rating',
#  'seller_return_rate',
#  'quantity',
#  'shipping_distance_km',
#  'product_page_views',
#  'total_customer_support',
#  'log_price']

# %%
X_train = X_train[all_features]
X_test = X_test[all_features]

# %% [markdown]
# ### Scale numeric columns

# %%
from sklearn.preprocessing import StandardScaler


scalar = StandardScaler()
X_train[numeric_columns] = scalar.fit_transform(X_train[numeric_columns])
X_test[numeric_columns] = scalar.fit_transform(X_test[numeric_columns])

# %% [markdown]
# ### Encoding

# %%
X_train = pd.get_dummies(X_train, columns = categorical_features, dtype = int)
X_test = pd.get_dummies(X_test, columns = categorical_features, dtype = int)

# %%
X_train
# Out:
#        fragile_item  warranty_available  delayed_delivery  \
# 3580              1                   1                 0
# 4973              1                   1                 0
# 1938              0                   0                 0
# 9346              0                   1                 0
# 6362              0                   0                 0
# ...             ...                 ...               ...
# 9158              1                   1                 0
# 11856             0                   0                 0
# 1556              0                   0                 0
# 8190              0                   0                 0
# 9125              0                   0                 0
#
#        wishlist_before_purchase  discount_percent  product_rating  \
# 3580                          0          1.404726       -1.248081
# 4973                          0         -0.840260       -0.618729
# 1938                          0          1.203452       -0.304054
# ...

# %%
X_train.shape
# Out:
# (9080, 85)

# %%
X_test.shape
# Out:
# (2271, 85)

# %% [markdown]
# ### Model Training

# %%
from sklearn.linear_model import LogisticRegression


lr = LogisticRegression(max_iter = 1000, class_weight = "balanced", random_state = 10)
lr.fit(X_train, y_train)
# Out:
# LogisticRegression(class_weight='balanced', max_iter=1000, random_state=10)

# %%
y_pred = lr.predict(X_test)

# %%
from sklearn.metrics import classification_report


report = classification_report(y_test, y_pred)
print(report)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.94      0.86      0.89      1581
#            1       0.72      0.87      0.79       690
#
#     accuracy                           0.86      2271
#    macro avg       0.83      0.86      0.84      2271
# weighted avg       0.87      0.86      0.86      2271

# %%
from sklearn.metrics import confusion_matrix


cm = confusion_matrix(y_test, y_pred)
cm
# Out:
# array([[1353,  228],
#        [  91,  599]])

# %%
from sklearn.metrics import ConfusionMatrixDisplay


disp = ConfusionMatrixDisplay(confusion_matrix = cm, display_labels = ["Not Returned", "Returned"])
disp.plot(cmap = "Blues")
plt.show()

# %%
from sklearn.tree import DecisionTreeClassifier


dt = DecisionTreeClassifier(class_weight = "balanced", random_state = 10)
dt.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier(class_weight='balanced', random_state=10)

# %%
y_pred = dt.predict(X_test)

# %%
from sklearn.metrics import classification_report


report = classification_report(y_test, y_pred)
print(report)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.83      0.85      0.84      1581
#            1       0.64      0.61      0.63       690
#
#     accuracy                           0.78      2271
#    macro avg       0.74      0.73      0.73      2271
# weighted avg       0.78      0.78      0.78      2271

# %%
from sklearn.metrics import confusion_matrix


cm = confusion_matrix(y_test, y_pred)
cm
# Out:
# array([[1350,  231],
#        [ 271,  419]])

# %%
from sklearn.metrics import ConfusionMatrixDisplay


disp = ConfusionMatrixDisplay(confusion_matrix = cm, display_labels = ["Not Returned", "Returned"])
disp.plot(cmap = "Blues")
plt.show()

# %%
from sklearn.ensemble import RandomForestClassifier


rf = RandomForestClassifier(n_estimators = 300, class_weight = "balanced", n_jobs = -1, random_state = 10)
rf.fit(X_train, y_train)
# Out:
# RandomForestClassifier(class_weight='balanced', n_estimators=300, n_jobs=-1,
#                        random_state=10)

# %%
y_pred = rf.predict(X_test)

# %%
from sklearn.metrics import classification_report


report = classification_report(y_test, y_pred)
print(report)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.89      0.91      0.90      1581
#            1       0.78      0.74      0.76       690
#
#     accuracy                           0.86      2271
#    macro avg       0.83      0.83      0.83      2271
# weighted avg       0.86      0.86      0.86      2271

# %%
from sklearn.metrics import confusion_matrix


cm = confusion_matrix(y_test, y_pred)
cm
# Out:
# array([[1434,  147],
#        [ 177,  513]])

# %%
from sklearn.metrics import ConfusionMatrixDisplay


disp = ConfusionMatrixDisplay(confusion_matrix = cm, display_labels = ["Not Returned", "Returned"])
disp.plot(cmap = "Blues")
plt.show()

# %%
from xgboost import XGBClassifier


xgb = XGBClassifier(n_estimators = 400, learning_rate = 0.05, max_depth = 5, subsample = 0.9, colsample_bytree = 0.9,  eval_metric = "logloss", n_jobs = -1, random_state = 10)
xgb.fit(X_train, y_train)
# Out:
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=0.9, device=None, early_stopping_rounds=None,
#               enable_categorical=True, eval_metric='logloss',
#               feature_types=None, feature_weights=None, gamma=None,
#               grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=0.05, max_bin=None,
#               max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=5, max_leaves=None,
#               min_child_weight=None, missing=nan, monotone_constraints=None,
#               multi_strategy=None, n_estimators=400, n_jobs=-1,
#               num_parallel_tree=None, ...)

# %%
y_pred = xgb.predict(X_test)

# %%
from sklearn.metrics import classification_report


report = classification_report(y_test, y_pred)
print(report)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.88      0.94      0.91      1581
#            1       0.83      0.71      0.77       690
#
#     accuracy                           0.87      2271
#    macro avg       0.86      0.82      0.84      2271
# weighted avg       0.87      0.87      0.86      2271

# %%
from sklearn.metrics import confusion_matrix


cm = confusion_matrix(y_test, y_pred)
cm
# Out:
# array([[1480,  101],
#        [ 199,  491]])

# %%
from sklearn.metrics import ConfusionMatrixDisplay


disp = ConfusionMatrixDisplay(confusion_matrix = cm, display_labels = ["Not Returned", "Returned"])
disp.plot(cmap = "Blues")
plt.show()

# %%
import joblib

model_data = {
    "model": xgb,
    "model_name": "XGBoost",
    "scaler": scalar,
    "numeric_features": numeric_columns,
    "binary_flags": binary_flags,
    "categorical_features": categorical_features,
    "threshold": 0.5,
}
joblib.dump(model_data, "artifacts/model_data.joblib")
print("Saved -> artifacts/model_data.joblib")
# Out:
# Saved -> artifacts/model_data.joblib
